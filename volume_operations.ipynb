// %% [markdown]
// # Volume operations
//
// This example shows how to use volume operators

// %%
#include "TIPL/tipl.hpp" // git clone http://github.com/frankyeh/TIPL/
using namespace tipl;

// %%
image<float,3> I;
I.load_from_file<tipl::io::nifti>("data/mni_icbm152_t1.nii");I

// %% [markdown]
// ## Basic Image Operations

// %%
swap_xy(I)

// %%
flip_x(I)

// %%
crop(I,v(30,30,0),v(150,150,80));
